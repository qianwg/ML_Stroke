# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.feature_selection import VarianceThreshold
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import make_classification
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, brier_score_loss
from sklearn.metrics import confusion_matrix

from skopt import BayesSearchCV
from skopt.space import Integer, Categorical, Real

import pickle
from kerastuner import HyperParameters
from kerastuner.tuners import BayesianOptimization
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam, Adamax, SGD, RMSprop
from tensorflow.keras.callbacks import EarlyStopping

import xgboost as xgb
import pandas as pd
import numpy as np
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_20244\1067859309.py:22: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner import HyperParameters

# %%
# Load data
DataStep7 = pd.read_feather('./Data/V2-DataStep7.feather')

# Define X and y
X = DataStep7.drop(columns=['Cluster'])
y = DataStep7['Cluster']

# 创建 LabelEncoder 对象
label_encoder = LabelEncoder()

# 将 y 中的标签转换为数值
y_encoded = label_encoder.fit_transform(y)

# Split data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Define the numeric and categorical columns
numeric_cols = X.select_dtypes(include=['float64', 'int64']).columns
categorical_cols = X.select_dtypes(include=['object', 'category']).columns

# Create a preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_cols),           # Normalize numeric columns
        ('cat', OneHotEncoder(), categorical_cols)  # One-hot encode categorical columns
    ])

# Create the complete pipeline with zero-variance feature removal
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('variance_threshold', VarianceThreshold())           # Remove zero-variance columns
])

# Fit the pipeline to the training data
pipeline.fit(X_train)

# Transform the training and test sets
X_train_transformed = pipeline.transform(X_train)
X_test_transformed = pipeline.transform(X_test)

# %%
# Initialize the XGBoost model
xgb_model = xgb.XGBClassifier()

# Define the search space for hyperparameters
param_space = {
    'n_estimators': Integer(100, 1000),
    'max_depth': Integer(3, 15),
    'min_child_weight': Integer(3, 15),
    'subsample': Real(0.7, 1.0, prior='uniform'),
    'eta': Real(1e-5, 1e-1, prior='log-uniform')
}

# Initialize the BayesSearchCV
bayes_search = BayesSearchCV(
    estimator=xgb_model,
    search_spaces=param_space,
    n_iter=50,  # Number of different hyperparameter combinations to try
    scoring='accuracy',
    cv=10,  # Number of cross-validation folds
    verbose=1,
    n_jobs=-1
)

# Fit the model using Bayesian Optimization
bayes_search.fit(X_train_transformed, y_train)

# Output the best parameters and best score
print("Best parameters found: ", bayes_search.best_params_)
print("Best score found: ", bayes_search.best_score_)

# Use the best model to evaluate on the test set
best_model = bayes_search.best_estimator_
test_accuracy = best_model.score(X_test_transformed, y_test)
print(f"Test accuracy: {test_accuracy}")
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Best parameters found:  OrderedDict([('eta', 0.04564436219404251), ('max_depth', 3), ('min_child_weight', 5), ('n_estimators', 100), ('subsample', 0.7)])
# Best score found:  0.7973202991234176
# Test accuracy: 0.8041918694612463

# %%
# 构建最佳超参数的模型
best_params = {'eta': 0.04564436219404251, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 100, 'subsample': 0.7}
xgboost_best = xgb.XGBClassifier(**best_params)


def save_results(metrics, fpr_train, tpr_train, fpr_val, tpr_val, filename):
    with open(filename, 'wb') as file:
        pickle.dump({
            'metrics': metrics,
            'fpr_train': fpr_train,
            'tpr_train': tpr_train,
            'fpr_val': fpr_val,
            'tpr_val': tpr_val
        }, file)

def evaluate_ann(model, X_train, y_train, X_val, y_val):
    # 训练集预测概率
    y_train_pred_prob = model.predict(X_train)  # 获取概率
    fpr_train, tpr_train, _ = roc_curve(y_train, y_train_pred_prob)
    roc_auc_train = auc(fpr_train, tpr_train)
    
    # 验证集预测概率
    y_val_pred_prob = model.predict(X_val)  # 获取概率
    fpr_val, tpr_val, _ = roc_curve(y_val, y_val_pred_prob)
    roc_auc_val = auc(fpr_val, tpr_val)
    
    y_train_pred = (y_train_pred_prob >= 0.5).astype(int)
    y_val_pred = (y_val_pred_prob >= 0.5).astype(int)

    # 计算各项指标
    metrics = {}

   # Accuracy
    metrics['train_accuracy'] = accuracy_score(y_train, y_train_pred)
    metrics['val_accuracy'] = accuracy_score(y_val, y_val_pred)
    
    # Precision
    metrics['train_precision'] = precision_score(y_train, y_train_pred)
    metrics['val_precision'] = precision_score(y_val, y_val_pred)
    
    # Sensitivity (Recall)
    metrics['train_sensitivity'] = recall_score(y_train, y_train_pred)
    metrics['val_sensitivity'] = recall_score(y_val, y_val_pred)
    
    # Specificity (TN / (TN + FP))
    tn, fp, fn, tp = confusion_matrix(y_train, y_train_pred).ravel()
    metrics['train_specificity'] = tn / (tn + fp)
    
    tn, fp, fn, tp = confusion_matrix(y_val, y_val_pred).ravel()
    metrics['val_specificity'] = tn / (tn + fp)
    
    # F1 Score
    metrics['train_f1'] = f1_score(y_train, y_train_pred)
    metrics['val_f1'] = f1_score(y_val, y_val_pred)
    
    # Brier Score
    metrics['train_brier'] = brier_score_loss(y_train, y_train_pred_prob)
    metrics['val_brier'] = brier_score_loss(y_val, y_val_pred_prob)

    metrics['train_roc_auc'] = roc_auc_train
    metrics['val_roc_auc'] = roc_auc_val

    return metrics, fpr_train, tpr_train, fpr_val, tpr_val

metrics, fpr_train, tpr_train, fpr_val, tpr_val = evaluate_ann(model, X_train_transformed, y_train, X_test_transformed, y_test)

# 示例使用
save_results(metrics, fpr_train, tpr_train, fpr_val, tpr_val, './Data/V2-xgboost_result.pkl')
# Out:
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step

# %%
def load_results(filename):
    with open(filename, 'rb') as file:
        data = pickle.load(file)
    return data['metrics'], data['fpr_train'], data['tpr_train'], data['fpr_val'], data['tpr_val']

# 示例使用
xgb_metrics, xgb_fpr_train, xgb_tpr_train, xgb_fpr_val, xgb_tpr_val = load_results('./Data/V2-xgboost_result.pkl')

# %%
# xgboost Fitting 10 folds for each of 5040 candidates, totalling 50400 fits
#Best parameters found:  Best parameters found:  OrderedDict([('eta', 0.004346323724542477), ('max_depth', 3), ('min_child_weight', 3), ('n_estimators', 1000), ('subsample', 0.7)])

# %% [markdown]
# # ANN

# %%
# 构建模型函数
def build_model(hp):
    model = Sequential()

    # 添加层数，使用 hp.Int 动态设置层数
    for i in range(hp.Int('num_layers', 1, 5)):  # 1到5层
        model.add(Dense(
            units=hp.Choice(f'units_{i}', [3, 5, 7, 10]),  # 每层的神经元数量
            activation='relu'
        ))
        model.add(Dropout(hp.Float('dropout_rate', 0, 0.5, step=0.05)))  # Dropout

    model.add(Dense(1, activation='sigmoid'))  # 最后一层，二分类

    # 优化器选择
    optimizer_options = {
        'Adam': Adam,
        'Adamax': Adamax,
        'SGD': SGD,
        'RMSprop': RMSprop
    }

    # 使用 hp.Choice 动态选择优化器
    optimizer_name = hp.Choice('optimizer', ['Adam', 'Adamax', 'SGD', 'RMSprop'])
    optimizer = optimizer_options[optimizer_name](
        learning_rate=hp.Float('learning_rate', 1e-5, 1e-1, sampling='log')
    )

    # 编译模型
    model.compile(
        optimizer=optimizer,
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

# 初始化 Bayesian Optimization Tuner
tuner = BayesianOptimization(
    build_model,  # 模型构建函数
    objective='val_accuracy',  # 优化目标
    max_trials=100,  # 最大搜索次数
    executions_per_trial=1,  # 每次搜索模型训练的次数
    directory='./dir',  # 保存搜索结果的目录
    project_name='V2-bayesion'  # 项目名称
)

# 输出搜索空间摘要
tuner.search_space_summary()


# Define early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss for early stopping
    patience=50,  # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore the weights of the best epoch once training is stopped
)

# 开始搜索最佳超参数
tuner.search(
    X_train_transformed, y_train,
    epochs=100,  # 设置训练的 epoch 数
    batch_size=HyperParameters().Choice('batch_size', [128, 256, 512, 1024]),  # 选择 batch_size
    validation_data=(X_test_transformed, y_test),
    callbacks=[early_stopping]  # 可选: 可以添加早停等回调
)

# 获得最佳超参数
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
# Out:
# Trial 100 Complete [00h 00m 12s]
# val_accuracy: 0.8050358891487122
#
# Best val_accuracy So Far: 0.807145893573761
# Total elapsed time: 00h 29m 41s

# %%
# 构建最佳超参数的模型
model = tuner.hypermodel.build(best_hps)
model.fit(
    X_train_transformed, y_train,
    validation_data=(X_test_transformed, y_test),
    epochs=100,
    batch_size=512
)

# 评估模型
test_loss, test_accuracy = model.evaluate(X_test_transformed, y_test)

print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

from sklearn.metrics import accuracy_score

# 预测概率
y_test_pred_prob = model.predict(X_test_transformed)

# 将概率转化为预测标签（假设阈值为0.5）
y_test_pred = (y_test_pred_prob >= 0.5).astype(int)

# 计算准确率
accuracy = accuracy_score(y_test, y_test_pred)

print(f"Test Accuracy: {accuracy}")
# Out:
# Epoch 1/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6845 - loss: 0.6579 - val_accuracy: 0.6932 - val_loss: 0.6060
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.6910 - loss: 0.5946 - val_accuracy: 0.6974 - val_loss: 0.5551
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.6962 - loss: 0.5512 - val_accuracy: 0.7070 - val_loss: 0.5178
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7125 - loss: 0.5110 - val_accuracy: 0.7208 - val_loss: 0.4922
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7250 - loss: 0.4942 - val_accuracy: 0.7372 - val_loss: 0.4751
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7343 - loss: 0.4809 - val_accuracy: 0.7483 - val_loss: 0.4639
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7467 - loss: 0.4707 - val_accuracy: 0.7551 - val_loss: 0.4561
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7582 - loss: 0.4644 - val_accuracy: 0.7592 - val_loss: 0.4504
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - accuracy: 0.7600 - loss: 0.4589 - val_accuracy: 0.7648 - val_loss: 0.4461
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.7664 - loss: 0.4528 - val_accuracy: 0.7675 - val_loss: 0.4425
# Epoch 11/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7717 - loss: 0.4510 - val_accuracy: 0.7727 - val_loss: 0.4396
# Epoch 12/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7714 - loss: 0.4503 - val_accuracy: 0.7766 - val_loss: 0.4371
# Epoch 13/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - accuracy: 0.7785 - loss: 0.4419 - val_accuracy: 0.7807 - val_loss: 0.4349
# Epoch 14/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.7753 - loss: 0.4489 - val_accuracy: 0.7837 - val_loss: 0.4330
# Epoch 15/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - accuracy: 0.7770 - loss: 0.4448 - val_accuracy: 0.7838 - val_loss: 0.4311
# Epoch 16/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7824 - loss: 0.4438 - val_accuracy: 0.7852 - val_loss: 0.4295
# Epoch 17/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7850 - loss: 0.4412 - val_accuracy: 0.7869 - val_loss: 0.4279
# Epoch 18/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7862 - loss: 0.4369 - val_accuracy: 0.7903 - val_loss: 0.4265
# Epoch 19/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7842 - loss: 0.4394 - val_accuracy: 0.7934 - val_loss: 0.4252
# Epoch 20/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7896 - loss: 0.4316 - val_accuracy: 0.7934 - val_loss: 0.4240
# Epoch 21/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7877 - loss: 0.4346 - val_accuracy: 0.7941 - val_loss: 0.4229
# Epoch 22/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7896 - loss: 0.4333 - val_accuracy: 0.7956 - val_loss: 0.4219
# Epoch 23/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - accuracy: 0.7888 - loss: 0.4383 - val_accuracy: 0.7977 - val_loss: 0.4210
# Epoch 24/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7951 - loss: 0.4271 - val_accuracy: 0.7980 - val_loss: 0.4201
# Epoch 25/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7902 - loss: 0.4333 - val_accuracy: 0.7991 - val_loss: 0.4193
# Epoch 26/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7948 - loss: 0.4281 - val_accuracy: 0.7994 - val_loss: 0.4185
# Epoch 27/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7916 - loss: 0.4305 - val_accuracy: 0.7990 - val_loss: 0.4179
# Epoch 28/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7898 - loss: 0.4318 - val_accuracy: 0.7991 - val_loss: 0.4172
# Epoch 29/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7906 - loss: 0.4320 - val_accuracy: 0.7988 - val_loss: 0.4166
# Epoch 30/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7947 - loss: 0.4261 - val_accuracy: 0.7987 - val_loss: 0.4161
# Epoch 31/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7956 - loss: 0.4244 - val_accuracy: 0.7983 - val_loss: 0.4156
# Epoch 32/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.7916 - loss: 0.4301 - val_accuracy: 0.7983 - val_loss: 0.4152
# Epoch 33/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7942 - loss: 0.4265 - val_accuracy: 0.7987 - val_loss: 0.4147
# Epoch 34/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7936 - loss: 0.4279 - val_accuracy: 0.7981 - val_loss: 0.4143
# Epoch 35/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - accuracy: 0.7950 - loss: 0.4245 - val_accuracy: 0.7990 - val_loss: 0.4139
# Epoch 36/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7992 - loss: 0.4189 - val_accuracy: 0.7995 - val_loss: 0.4136
# Epoch 37/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7945 - loss: 0.4237 - val_accuracy: 0.7998 - val_loss: 0.4133
# Epoch 38/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7944 - loss: 0.4247 - val_accuracy: 0.8003 - val_loss: 0.4129
# Epoch 39/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7986 - loss: 0.4202 - val_accuracy: 0.8005 - val_loss: 0.4127
# Epoch 40/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7992 - loss: 0.4150 - val_accuracy: 0.8007 - val_loss: 0.4124
# Epoch 41/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.8000 - loss: 0.4202 - val_accuracy: 0.8010 - val_loss: 0.4121
# Epoch 42/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7942 - loss: 0.4254 - val_accuracy: 0.8012 - val_loss: 0.4119
# Epoch 43/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.7918 - loss: 0.4245 - val_accuracy: 0.8014 - val_loss: 0.4117
# Epoch 44/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7981 - loss: 0.4189 - val_accuracy: 0.8017 - val_loss: 0.4114
# Epoch 45/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7919 - loss: 0.4285 - val_accuracy: 0.8019 - val_loss: 0.4112
# Epoch 46/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7964 - loss: 0.4218 - val_accuracy: 0.8010 - val_loss: 0.4111
# Epoch 47/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7938 - loss: 0.4202 - val_accuracy: 0.8015 - val_loss: 0.4109
# Epoch 48/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.7942 - loss: 0.4200 - val_accuracy: 0.8014 - val_loss: 0.4107
# Epoch 49/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - accuracy: 0.7972 - loss: 0.4199 - val_accuracy: 0.8014 - val_loss: 0.4106
# Epoch 50/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.7941 - loss: 0.4244 - val_accuracy: 0.8019 - val_loss: 0.4104
# Epoch 51/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7949 - loss: 0.4191 - val_accuracy: 0.8011 - val_loss: 0.4102
# Epoch 52/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7974 - loss: 0.4173 - val_accuracy: 0.8011 - val_loss: 0.4101
# Epoch 53/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7969 - loss: 0.4168 - val_accuracy: 0.8018 - val_loss: 0.4099
# Epoch 54/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7953 - loss: 0.4208 - val_accuracy: 0.8011 - val_loss: 0.4098
# Epoch 55/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - accuracy: 0.8003 - loss: 0.4166 - val_accuracy: 0.8018 - val_loss: 0.4096
# Epoch 56/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7968 - loss: 0.4181 - val_accuracy: 0.8024 - val_loss: 0.4095
# Epoch 57/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7950 - loss: 0.4221 - val_accuracy: 0.8022 - val_loss: 0.4094
# Epoch 58/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7963 - loss: 0.4173 - val_accuracy: 0.8019 - val_loss: 0.4093
# Epoch 59/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.7975 - loss: 0.4172 - val_accuracy: 0.8015 - val_loss: 0.4092
# Epoch 60/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7967 - loss: 0.4160 - val_accuracy: 0.8019 - val_loss: 0.4090
# Epoch 61/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7934 - loss: 0.4244 - val_accuracy: 0.8014 - val_loss: 0.4089
# Epoch 62/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7971 - loss: 0.4163 - val_accuracy: 0.8019 - val_loss: 0.4088
# Epoch 63/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7929 - loss: 0.4228 - val_accuracy: 0.8024 - val_loss: 0.4087
# Epoch 64/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7991 - loss: 0.4132 - val_accuracy: 0.8022 - val_loss: 0.4086
# Epoch 65/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7962 - loss: 0.4156 - val_accuracy: 0.8019 - val_loss: 0.4085
# Epoch 66/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7967 - loss: 0.4171 - val_accuracy: 0.8022 - val_loss: 0.4084
# Epoch 67/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7936 - loss: 0.4200 - val_accuracy: 0.8022 - val_loss: 0.4083
# Epoch 68/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7987 - loss: 0.4156 - val_accuracy: 0.8025 - val_loss: 0.4082
# Epoch 69/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7981 - loss: 0.4181 - val_accuracy: 0.8025 - val_loss: 0.4081
# Epoch 70/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7964 - loss: 0.4209 - val_accuracy: 0.8028 - val_loss: 0.4081
# Epoch 71/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7941 - loss: 0.4221 - val_accuracy: 0.8032 - val_loss: 0.4080
# Epoch 72/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7960 - loss: 0.4223 - val_accuracy: 0.8035 - val_loss: 0.4079
# Epoch 73/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - accuracy: 0.8015 - loss: 0.4100 - val_accuracy: 0.8029 - val_loss: 0.4078
# Epoch 74/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - accuracy: 0.7997 - loss: 0.4130 - val_accuracy: 0.8029 - val_loss: 0.4078
# Epoch 75/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7975 - loss: 0.4169 - val_accuracy: 0.8026 - val_loss: 0.4077
# Epoch 76/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7990 - loss: 0.4138 - val_accuracy: 0.8028 - val_loss: 0.4076
# Epoch 77/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7954 - loss: 0.4204 - val_accuracy: 0.8024 - val_loss: 0.4075
# Epoch 78/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7967 - loss: 0.4197 - val_accuracy: 0.8029 - val_loss: 0.4074
# Epoch 79/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7985 - loss: 0.4184 - val_accuracy: 0.8031 - val_loss: 0.4074
# Epoch 80/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7997 - loss: 0.4169 - val_accuracy: 0.8031 - val_loss: 0.4073
# Epoch 81/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.8002 - loss: 0.4181 - val_accuracy: 0.8031 - val_loss: 0.4073
# Epoch 82/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7955 - loss: 0.4205 - val_accuracy: 0.8032 - val_loss: 0.4072
# Epoch 83/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7965 - loss: 0.4198 - val_accuracy: 0.8033 - val_loss: 0.4072
# Epoch 84/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7985 - loss: 0.4145 - val_accuracy: 0.8035 - val_loss: 0.4071
# Epoch 85/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7977 - loss: 0.4177 - val_accuracy: 0.8032 - val_loss: 0.4071
# Epoch 86/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7989 - loss: 0.4142 - val_accuracy: 0.8031 - val_loss: 0.4070
# Epoch 87/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.8017 - loss: 0.4153 - val_accuracy: 0.8029 - val_loss: 0.4069
# Epoch 88/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7951 - loss: 0.4162 - val_accuracy: 0.8035 - val_loss: 0.4069
# Epoch 89/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7945 - loss: 0.4232 - val_accuracy: 0.8026 - val_loss: 0.4069
# Epoch 90/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.8024 - loss: 0.4126 - val_accuracy: 0.8029 - val_loss: 0.4068
# Epoch 91/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.8021 - loss: 0.4124 - val_accuracy: 0.8028 - val_loss: 0.4068
# Epoch 92/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.8021 - loss: 0.4115 - val_accuracy: 0.8022 - val_loss: 0.4067
# Epoch 93/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.8003 - loss: 0.4146 - val_accuracy: 0.8024 - val_loss: 0.4067
# Epoch 94/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7940 - loss: 0.4200 - val_accuracy: 0.8032 - val_loss: 0.4066
# Epoch 95/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.8010 - loss: 0.4144 - val_accuracy: 0.8033 - val_loss: 0.4066
# Epoch 96/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7964 - loss: 0.4185 - val_accuracy: 0.8026 - val_loss: 0.4065
# Epoch 97/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7973 - loss: 0.4190 - val_accuracy: 0.8029 - val_loss: 0.4065
# Epoch 98/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.7978 - loss: 0.4162 - val_accuracy: 0.8025 - val_loss: 0.4064
# Epoch 99/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.8043 - loss: 0.4088 - val_accuracy: 0.8029 - val_loss: 0.4064
# Epoch 100/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.7995 - loss: 0.4170 - val_accuracy: 0.8031 - val_loss: 0.4064
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - accuracy: 0.8051 - loss: 0.3980
# Test Loss: 0.40638139843940735
# Test Accuracy: 0.8030665516853333
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step
# Test Accuracy: 0.8030665353776902

# %%
# 构建最佳超参数的模型
model = tuner.hypermodel.build(best_hps)
model.fit(
    X_train_transformed, y_train,
    validation_data=(X_test_transformed, y_test),
    epochs=100,
    batch_size=512
)

def save_results(metrics, fpr_train, tpr_train, fpr_val, tpr_val, filename):
    with open(filename, 'wb') as file:
        pickle.dump({
            'metrics': metrics,
            'fpr_train': fpr_train,
            'tpr_train': tpr_train,
            'fpr_val': fpr_val,
            'tpr_val': tpr_val
        }, file)

def evaluate_ann(model, X_train, y_train, X_val, y_val):
    # 训练集预测概率
    y_train_pred_prob = model.predict(X_train)  # 获取概率
    fpr_train, tpr_train, _ = roc_curve(y_train, y_train_pred_prob)
    roc_auc_train = auc(fpr_train, tpr_train)
    
    # 验证集预测概率
    y_val_pred_prob = model.predict(X_val)  # 获取概率
    fpr_val, tpr_val, _ = roc_curve(y_val, y_val_pred_prob)
    roc_auc_val = auc(fpr_val, tpr_val)
    
    y_train_pred = (y_train_pred_prob >= 0.5).astype(int)
    y_val_pred = (y_val_pred_prob >= 0.5).astype(int)

    # 计算各项指标
    metrics = {}

   # Accuracy
    metrics['train_accuracy'] = accuracy_score(y_train, y_train_pred)
    metrics['val_accuracy'] = accuracy_score(y_val, y_val_pred)
    
    # Precision
    metrics['train_precision'] = precision_score(y_train, y_train_pred)
    metrics['val_precision'] = precision_score(y_val, y_val_pred)
    
    # Sensitivity (Recall)
    metrics['train_sensitivity'] = recall_score(y_train, y_train_pred)
    metrics['val_sensitivity'] = recall_score(y_val, y_val_pred)
    
    # Specificity (TN / (TN + FP))
    tn, fp, fn, tp = confusion_matrix(y_train, y_train_pred).ravel()
    metrics['train_specificity'] = tn / (tn + fp)
    
    tn, fp, fn, tp = confusion_matrix(y_val, y_val_pred).ravel()
    metrics['val_specificity'] = tn / (tn + fp)
    
    # F1 Score
    metrics['train_f1'] = f1_score(y_train, y_train_pred)
    metrics['val_f1'] = f1_score(y_val, y_val_pred)
    
    # Brier Score
    metrics['train_brier'] = brier_score_loss(y_train, y_train_pred_prob)
    metrics['val_brier'] = brier_score_loss(y_val, y_val_pred_prob)

    metrics['train_roc_auc'] = roc_auc_train
    metrics['val_roc_auc'] = roc_auc_val

    return metrics, fpr_train, tpr_train, fpr_val, tpr_val

metrics, fpr_train, tpr_train, fpr_val, tpr_val = evaluate_ann(model, X_train_transformed, y_train, X_test_transformed, y_test)

# 示例使用
save_results(metrics, fpr_train, tpr_train, fpr_val, tpr_val, './Data/V2-ann_result.pkl')
# Out:
# Epoch 1/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7031 - loss: 0.7589 - val_accuracy: 0.7083 - val_loss: 0.7038
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7033 - loss: 0.6954 - val_accuracy: 0.7083 - val_loss: 0.6483
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7002 - loss: 0.6450 - val_accuracy: 0.7081 - val_loss: 0.6036
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7047 - loss: 0.5984 - val_accuracy: 0.7087 - val_loss: 0.5673
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - accuracy: 0.6992 - loss: 0.5735 - val_accuracy: 0.7087 - val_loss: 0.5382
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7069 - loss: 0.5360 - val_accuracy: 0.7069 - val_loss: 0.5152
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7013 - loss: 0.5196 - val_accuracy: 0.7083 - val_loss: 0.4969
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7083 - loss: 0.4984 - val_accuracy: 0.7076 - val_loss: 0.4827
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7105 - loss: 0.4843 - val_accuracy: 0.7209 - val_loss: 0.4715
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7129 - loss: 0.4770 - val_accuracy: 0.7299 - val_loss: 0.4628
# Epoch 11/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7242 - loss: 0.4662 - val_accuracy: 0.7427 - val_loss: 0.4559
# Epoch 12/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7417 - loss: 0.4594 - val_accuracy: 0.7538 - val_loss: 0.4506
# Epoch 13/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7466 - loss: 0.4563 - val_accuracy: 0.7638 - val_loss: 0.4464
# Epoch 14/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7575 - loss: 0.4565 - val_accuracy: 0.7689 - val_loss: 0.4431
# Epoch 15/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7651 - loss: 0.4515 - val_accuracy: 0.7702 - val_loss: 0.4404
# Epoch 16/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7662 - loss: 0.4496 - val_accuracy: 0.7724 - val_loss: 0.4382
# Epoch 17/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7661 - loss: 0.4494 - val_accuracy: 0.7734 - val_loss: 0.4363
# Epoch 18/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.7676 - loss: 0.4481 - val_accuracy: 0.7754 - val_loss: 0.4347
# Epoch 19/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7695 - loss: 0.4414 - val_accuracy: 0.7770 - val_loss: 0.4333
# Epoch 20/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7723 - loss: 0.4425 - val_accuracy: 0.7794 - val_loss: 0.4320
# Epoch 21/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7722 - loss: 0.4416 - val_accuracy: 0.7810 - val_loss: 0.4309
# Epoch 22/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7716 - loss: 0.4420 - val_accuracy: 0.7810 - val_loss: 0.4298
# Epoch 23/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7740 - loss: 0.4392 - val_accuracy: 0.7824 - val_loss: 0.4288
# Epoch 24/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7735 - loss: 0.4392 - val_accuracy: 0.7832 - val_loss: 0.4279
# Epoch 25/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7784 - loss: 0.4354 - val_accuracy: 0.7837 - val_loss: 0.4270
# Epoch 26/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7799 - loss: 0.4354 - val_accuracy: 0.7839 - val_loss: 0.4262
# Epoch 27/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.7754 - loss: 0.4378 - val_accuracy: 0.7855 - val_loss: 0.4255
# Epoch 28/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7782 - loss: 0.4331 - val_accuracy: 0.7855 - val_loss: 0.4248
# Epoch 29/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7747 - loss: 0.4391 - val_accuracy: 0.7867 - val_loss: 0.4241
# Epoch 30/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - accuracy: 0.7750 - loss: 0.4375 - val_accuracy: 0.7867 - val_loss: 0.4235
# Epoch 31/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - accuracy: 0.7782 - loss: 0.4333 - val_accuracy: 0.7866 - val_loss: 0.4229
# Epoch 32/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7801 - loss: 0.4344 - val_accuracy: 0.7883 - val_loss: 0.4224
# Epoch 33/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7804 - loss: 0.4356 - val_accuracy: 0.7896 - val_loss: 0.4219
# Epoch 34/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.7797 - loss: 0.4316 - val_accuracy: 0.7896 - val_loss: 0.4214
# Epoch 35/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7815 - loss: 0.4329 - val_accuracy: 0.7900 - val_loss: 0.4209
# Epoch 36/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7836 - loss: 0.4291 - val_accuracy: 0.7913 - val_loss: 0.4205
# Epoch 37/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7833 - loss: 0.4262 - val_accuracy: 0.7910 - val_loss: 0.4201
# Epoch 38/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.7820 - loss: 0.4313 - val_accuracy: 0.7907 - val_loss: 0.4196
# Epoch 39/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7844 - loss: 0.4282 - val_accuracy: 0.7910 - val_loss: 0.4192
# Epoch 40/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7834 - loss: 0.4309 - val_accuracy: 0.7913 - val_loss: 0.4188
# Epoch 41/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - accuracy: 0.7816 - loss: 0.4275 - val_accuracy: 0.7904 - val_loss: 0.4185
# Epoch 42/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7838 - loss: 0.4272 - val_accuracy: 0.7908 - val_loss: 0.4181
# Epoch 43/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7823 - loss: 0.4302 - val_accuracy: 0.7914 - val_loss: 0.4178
# Epoch 44/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.7832 - loss: 0.4315 - val_accuracy: 0.7917 - val_loss: 0.4174
# Epoch 45/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - accuracy: 0.7889 - loss: 0.4222 - val_accuracy: 0.7914 - val_loss: 0.4171
# Epoch 46/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7863 - loss: 0.4248 - val_accuracy: 0.7918 - val_loss: 0.4168
# Epoch 47/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7840 - loss: 0.4305 - val_accuracy: 0.7914 - val_loss: 0.4164
# Epoch 48/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7878 - loss: 0.4268 - val_accuracy: 0.7917 - val_loss: 0.4161
# Epoch 49/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7864 - loss: 0.4266 - val_accuracy: 0.7907 - val_loss: 0.4158
# Epoch 50/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7889 - loss: 0.4250 - val_accuracy: 0.7913 - val_loss: 0.4155
# Epoch 51/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7889 - loss: 0.4230 - val_accuracy: 0.7911 - val_loss: 0.4152
# Epoch 52/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7887 - loss: 0.4255 - val_accuracy: 0.7918 - val_loss: 0.4150
# Epoch 53/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7917 - loss: 0.4225 - val_accuracy: 0.7927 - val_loss: 0.4147
# Epoch 54/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7877 - loss: 0.4249 - val_accuracy: 0.7935 - val_loss: 0.4144
# Epoch 55/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7868 - loss: 0.4267 - val_accuracy: 0.7936 - val_loss: 0.4141
# Epoch 56/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7891 - loss: 0.4263 - val_accuracy: 0.7942 - val_loss: 0.4139
# Epoch 57/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - accuracy: 0.7894 - loss: 0.4232 - val_accuracy: 0.7942 - val_loss: 0.4136
# Epoch 58/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7893 - loss: 0.4222 - val_accuracy: 0.7942 - val_loss: 0.4134
# Epoch 59/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - accuracy: 0.7881 - loss: 0.4241 - val_accuracy: 0.7948 - val_loss: 0.4131
# Epoch 60/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7938 - loss: 0.4211 - val_accuracy: 0.7955 - val_loss: 0.4129
# Epoch 61/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7905 - loss: 0.4208 - val_accuracy: 0.7956 - val_loss: 0.4127
# Epoch 62/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7922 - loss: 0.4198 - val_accuracy: 0.7953 - val_loss: 0.4125
# Epoch 63/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.7921 - loss: 0.4199 - val_accuracy: 0.7949 - val_loss: 0.4123
# Epoch 64/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 0.7940 - loss: 0.4188 - val_accuracy: 0.7953 - val_loss: 0.4121
# Epoch 65/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7913 - loss: 0.4257 - val_accuracy: 0.7962 - val_loss: 0.4119
# Epoch 66/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7915 - loss: 0.4241 - val_accuracy: 0.7966 - val_loss: 0.4116
# Epoch 67/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - accuracy: 0.7910 - loss: 0.4188 - val_accuracy: 0.7969 - val_loss: 0.4114
# Epoch 68/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7891 - loss: 0.4241 - val_accuracy: 0.7966 - val_loss: 0.4112
# Epoch 69/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7890 - loss: 0.4255 - val_accuracy: 0.7967 - val_loss: 0.4110
# Epoch 70/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7949 - loss: 0.4194 - val_accuracy: 0.7963 - val_loss: 0.4108
# Epoch 71/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7899 - loss: 0.4252 - val_accuracy: 0.7967 - val_loss: 0.4106
# Epoch 72/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7925 - loss: 0.4189 - val_accuracy: 0.7970 - val_loss: 0.4105
# Epoch 73/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7950 - loss: 0.4183 - val_accuracy: 0.7972 - val_loss: 0.4103
# Epoch 74/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - accuracy: 0.7940 - loss: 0.4192 - val_accuracy: 0.7976 - val_loss: 0.4101
# Epoch 75/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.7914 - loss: 0.4213 - val_accuracy: 0.7977 - val_loss: 0.4099
# Epoch 76/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7877 - loss: 0.4267 - val_accuracy: 0.7977 - val_loss: 0.4098
# Epoch 77/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.7959 - loss: 0.4157 - val_accuracy: 0.7980 - val_loss: 0.4097
# Epoch 78/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7878 - loss: 0.4256 - val_accuracy: 0.7988 - val_loss: 0.4095
# Epoch 79/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7947 - loss: 0.4168 - val_accuracy: 0.7986 - val_loss: 0.4094
# Epoch 80/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7948 - loss: 0.4208 - val_accuracy: 0.7988 - val_loss: 0.4092
# Epoch 81/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7928 - loss: 0.4211 - val_accuracy: 0.7991 - val_loss: 0.4091
# Epoch 82/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7944 - loss: 0.4184 - val_accuracy: 0.7990 - val_loss: 0.4090
# Epoch 83/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7985 - loss: 0.4139 - val_accuracy: 0.7994 - val_loss: 0.4088
# Epoch 84/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - accuracy: 0.7985 - loss: 0.4169 - val_accuracy: 0.7993 - val_loss: 0.4087
# Epoch 85/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7939 - loss: 0.4218 - val_accuracy: 0.7994 - val_loss: 0.4086
# Epoch 86/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7970 - loss: 0.4157 - val_accuracy: 0.8001 - val_loss: 0.4085
# Epoch 87/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7961 - loss: 0.4194 - val_accuracy: 0.8003 - val_loss: 0.4084
# Epoch 88/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7912 - loss: 0.4215 - val_accuracy: 0.8001 - val_loss: 0.4083
# Epoch 89/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - accuracy: 0.7931 - loss: 0.4193 - val_accuracy: 0.8005 - val_loss: 0.4081
# Epoch 90/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7915 - loss: 0.4214 - val_accuracy: 0.8004 - val_loss: 0.4081
# Epoch 91/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7929 - loss: 0.4173 - val_accuracy: 0.8005 - val_loss: 0.4079
# Epoch 92/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7973 - loss: 0.4155 - val_accuracy: 0.8004 - val_loss: 0.4079
# Epoch 93/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7985 - loss: 0.4140 - val_accuracy: 0.8007 - val_loss: 0.4078
# Epoch 94/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7943 - loss: 0.4177 - val_accuracy: 0.8007 - val_loss: 0.4077
# Epoch 95/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7957 - loss: 0.4166 - val_accuracy: 0.8007 - val_loss: 0.4076
# Epoch 96/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7949 - loss: 0.4197 - val_accuracy: 0.8003 - val_loss: 0.4075
# Epoch 97/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7924 - loss: 0.4176 - val_accuracy: 0.8004 - val_loss: 0.4074
# Epoch 98/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.7944 - loss: 0.4153 - val_accuracy: 0.8007 - val_loss: 0.4074
# Epoch 99/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7906 - loss: 0.4230 - val_accuracy: 0.8004 - val_loss: 0.4073
# Epoch 100/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.7917 - loss: 0.4196 - val_accuracy: 0.8007 - val_loss: 0.4072
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step

# %%
def load_results(filename):
    with open(filename, 'rb') as file:
        data = pickle.load(file)
    return data['metrics'], data['fpr_train'], data['tpr_train'], data['fpr_val'], data['tpr_val']

# 示例使用
ann_metrics, ann_fpr_train, ann_tpr_train, ann_fpr_val, ann_tpr_val = load_results('./Data/V2-ann_result.pkl')
